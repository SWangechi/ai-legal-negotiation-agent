# %% [markdown]
# Adaptive Learning Test Notebook
# -------------------------------
# Use this notebook to verify that feedback is being correctly loaded,
# sentiment-analyzed, and embedded into ChromaDB memory.

# %%
from backend.adaptive_trainer import update_memory_with_feedback
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from backend.adaptive_trainer import update_memory_with_feedback
#
# ModuleNotFoundError: No module named 'backend'

# %%
update_memory_with_feedback()
